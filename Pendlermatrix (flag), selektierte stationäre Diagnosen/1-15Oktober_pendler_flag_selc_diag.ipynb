# %% [markdown]
# # 274to289 (1-15 Oktober)

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from matplotlib import rcParams
import shap
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import seaborn as sns

from catboost import Pool, CatBoostRegressor, cv 
from catboost.utils import eval_metric

# %% [markdown]
# # Data

# %%
df = pd.read_stata('T:\\COVID19\\Makrodaten\\Oct1-15P.dta')
# Out:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.

# %%
Y = df['std_inz_AGS_274to289']
X = df.loc[:, ~df.columns.isin(['std_inz_AGS_274to289'])]
f_names = list(X.columns)
print("Number of features: ", len(X.columns))
# Out:
# Number of features:  957

# %% [markdown]
# # Feature Correlation

# %%
corr = X.corr()
sns.heatmap(corr)

# %%
pairs = []

for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if abs(corr.iloc[i,j]) >= 0.8:
            pairs.append(corr.columns[[i,j]][0])
            pairs.append(corr.columns[[i,j]][1])
            print(corr.columns[[i,j]],corr.iloc[i,j])
# Out:
# Index(['D_Lebens', 'D_v599'], dtype='object') 0.9204456724863153
# Index(['D_Lebens', 'HC_Vorzeitig'], dtype='object') -0.853570725481162
# Index(['UE_ArbquoteJ', 'PO_SGBII_'], dtype='object') 0.8310490758054104
# Index(['UE_AntreBesc', 'UE_AnteBesch'], dtype='object') -0.8073819685836338
# Index(['UE_BesePrima', 'UE_v305'], dtype='object') 0.8333318048923829
# Index(['UE_Erwerb', 'SSE_Einwohner'], dtype='object') 0.8980642650031009
# Index(['UE_Erwerb', 'SSE_v967'], dtype='object') 0.9540188242864167
# Index(['UE_Erwerb', 'SSE_Siedlungs'], dtype='object') 0.8849779610806378
# Index(['UE_Erwerb', 'SSE_AnteilErh'], dtype='object') 0.8137246324046928
# Index(['UE_Erwerb', 'SSE_AnteilFre'], dtype='object') -0.897382514680414
# Index(['UE_v190', 'PRE_v727'], dtype='object') 0.9155820449459644
# Index(['UE_v202', 'PRE_v733'], dtype='object') 0.930634945720119
# Index(['UE_v202', 'PRE_v739'], dtype='object') 0.8741009848581435
# Index(['UE_v251', 'UE_v381'], dtype='object') 0.86208012245028
# Index(['UE_Dienst', 'HC_aerztever'], dtype='object') 0.8412924703560578
# Index(['UE_Dienst', 'IS_endlersaldo2017'], dtype='object') 0.8315932043426256
# Index(['UE_v324', 'INC_v793'], dtype='object') 0.8362487423480941
# Index(['PRE_v652', 'PRE_v698'], dtype='object') 0.8858035183885867
# Index(['PRE_v733', 'PRE_v739'], dtype='object') 0.9508453295146861
# Index(['INC_Schuldn', 'PO_SGBII_'], dtype='object') 0.8981304431555756
# Index(['INC_Bruttow', 'INC_v1175'], dtype='object') 0.9999935949643357
# Index(['SSE_Laendlich', 'IS_v1071'], dtype='object') -0.8177314051332925
# Index(['SSE_Einwohner', 'SSE_v967'], dtype='object') 0.8905264428231038
# Index(['SSE_Einwohner', 'SSE_Siedlungs'], dtype='object') 0.8533614996231192
# Index(['SSE_Einwohner', 'SSE_AnteilErh'], dtype='object') 0.8134785464691022
# Index(['SSE_Einwohner', 'SSE_AnteilFre'], dtype='object') -0.8640992313747137
# Index(['SSE_v967', 'SSE_Siedlungs'], dtype='object') 0.8720916831699117
# Index(['SSE_v967', 'SSE_AnteilErh'], dtype='object') 0.8255458348560302
# Index(['SSE_v967', 'SSE_AnteilFre'], dtype='object') -0.8858229333482592
# Index(['SSE_Siedlungs', 'SSE_AnteilFre'], dtype='object') -0.8634778505034867
# Index(['SSE_Siedlungs', 'IS_v1069'], dtype='object') 0.844927826757289
# Index(['SSE_Siedlungs', 'IS_v1071'], dtype='object') 0.8823899284566952
# Index(['SSE_AnteilErh', 'SSE_AnteilFre'], dtype='object') -0.8724253553339393
# Index(['SSE_AnteilFre', 'IS_v1069'], dtype='object') -0.8110796205336783
# Index(['SSE_AnteilFre', 'IS_v1071'], dtype='object') -0.8302394223639652
# Index(['SSE_Anteilnat', 'SSE_AnteilWas'], dtype='object') 0.8090731085924177
# Index(['HC_Pflegehei', 'HC_Pflegehe'], dtype='object') 0.8670502900968139
# Index(['IS_v1069', 'IS_v1071'], dtype='object') 0.9525272245218408
# Index(['IS_v1070', 'IS_v1071'], dtype='object') -0.8001961067943603
# Index(['IS_v1072', 'IS_v1073'], dtype='object') -0.8862851885119565
# Index(['SSE_weighted_mean_pm10_2016', 'SSE_grand_mean_pm10_2016'], dtype='object') 0.9955938323297788
# Index(['flag100_to_1002', 'flag100_from_1058'], dtype='object') 0.8114788872808636
# Index(['flag100_to_1056', 'flag100_to_1060'], dtype='object') 0.8774020123598842
# Index(['flag100_to_1058', 'flag100_from_1058'], dtype='object') 0.8312389530013099
# Index(['flag100_to_1058', 'flag100_from_1059'], dtype='object') 0.8327004920490784
# Index(['flag100_to_3102', 'flag100_to_3158'], dtype='object') 0.8313003953239237
# Index(['flag100_to_3102', 'flag100_from_3153'], dtype='object') 0.8089667018660212
# Index(['flag100_to_3151', 'flag100_to_3154'], dtype='object') 0.8259569652794043
# Index(['flag100_to_3151', 'flag100_from_3151'], dtype='object') 0.8259569652793832
# Index(['flag100_to_3154', 'flag100_to_3158'], dtype='object') 0.831300395323924
# Index(['flag100_to_3157', 'flag100_to_3158'], dtype='object') 0.8130536130535891
# Index(['flag100_to_3157', 'flag100_from_3157'], dtype='object') 0.8665901232554585
# Index(['flag100_to_3158', 'flag100_from_3158'], dtype='object') 0.8665901232554585
# Index(['flag100_to_3251', 'flag100_from_3251'], dtype='object') 0.8354338065299998
# Index(['flag100_to_3255', 'flag100_from_3255'], dtype='object') 0.9416087749699209
# Index(['flag100_to_3356', 'flag100_from_3356'], dtype='object') 0.8736868677440599
# Index(['flag100_to_3357', 'flag100_from_3357'], dtype='object') 0.8138386663044637
# Index(['flag100_to_3358', 'flag100_from_3358'], dtype='object') 0.8768929970683319
# Index(['flag100_to_3360', 'flag100_from_3360'], dtype='object') 0.8166710620645115
# Index(['flag100_to_3361', 'flag100_from_3361'], dtype='object') 0.8443430788621834
# Index(['flag100_to_3404', 'flag100_from_3404'], dtype='object') 0.804569717518529
# Index(['flag100_to_3451', 'flag100_from_3451'], dtype='object') 0.8773475542674042
# Index(['flag100_to_3452', 'flag100_to_3457'], dtype='object') 0.8166710620644857
# Index(['flag100_to_3452', 'flag100_from_3452'], dtype='object') 0.9140959725792633
# Index(['flag100_to_3452', 'flag100_from_3457'], dtype='object') 0.8138386663044647
# Index(['flag100_to_3455', 'flag100_from_3455'], dtype='object') 0.8277942546916048
# Index(['flag100_to_3457', 'flag100_from_3457'], dtype='object') 0.8112592171905089
# Index(['flag100_to_3458', 'flag100_from_3458'], dtype='object') 0.8394782218607001
# Index(['flag100_to_3461', 'flag100_from_3461'], dtype='object') 0.9561988492548001
# Index(['flag100_to_4012', 'flag100_from_4012'], dtype='object') 0.8627051663700496
# Index(['flag100_to_5112', 'flag100_to_5119'], dtype='object') 0.8347245696010339
# Index(['flag100_to_5112', 'flag100_to_5124'], dtype='object') 0.8215902807548654
# Index(['flag100_to_5112', 'flag100_from_5112'], dtype='object') 0.8582522153278823
# Index(['flag100_to_5112', 'flag100_from_5158'], dtype='object') 0.8304564762366259
# Index(['flag100_to_5116', 'flag100_to_5166'], dtype='object') 0.8766153846153855
# Index(['flag100_to_5116', 'flag100_from_5114'], dtype='object') 0.8183442555964551
# Index(['flag100_to_5116', 'flag100_from_5116'], dtype='object') 0.8183442555964553
# Index(['flag100_to_5117', 'flag100_from_5117'], dtype='object') 0.8728292869756038
# Index(['flag100_to_5117', 'flag100_from_5119'], dtype='object') 0.838393458696896
# Index(['flag100_to_5119', 'flag100_to_5124'], dtype='object') 0.8265393490926184
# Index(['flag100_to_5119', 'flag100_to_5170'], dtype='object') 0.8348978919631103
# Index(['flag100_to_5119', 'flag100_from_5117'], dtype='object') 0.8055978142030323
# Index(['flag100_to_5119', 'flag100_from_5119'], dtype='object') 0.8437246067260519
# Index(['flag100_to_5119', 'flag100_from_5170'], dtype='object') 0.8204613129611875
# Index(['flag100_to_5119', 'flag100_from_5513'], dtype='object') 0.8159620525776287
# Index(['flag100_to_5120', 'flag100_from_5120'], dtype='object') 0.9107842206157869
# Index(['flag100_to_5122', 'flag100_from_5122'], dtype='object') 0.8339190649843884
# Index(['flag100_to_5124', 'flag100_to_5162'], dtype='object') 0.834323766263627
# Index(['flag100_to_5124', 'flag100_from_5124'], dtype='object') 0.8779299847793072
# Index(['flag100_to_5124', 'flag100_from_5158'], dtype='object') 0.8151037698336895
# Index(['flag100_to_5124', 'flag100_from_5911'], dtype='object') 0.8247960009766553
# Index(['flag100_to_5158', 'flag100_from_5158'], dtype='object') 0.8251318971853945
# Index(['flag100_to_5158', 'flag100_from_5911'], dtype='object') 0.835563941659803
# Index(['flag100_to_5162', 'flag100_to_5362'], dtype='object') 0.8195627954054042
# Index(['flag100_to_5162', 'flag100_from_5124'], dtype='object') 0.834323766263627
# Index(['flag100_to_5162', 'flag100_from_5158'], dtype='object') 0.8019021054947807
# Index(['flag100_to_5162', 'flag100_from_5162'], dtype='object') 0.8254415743699307
# Index(['flag100_to_5166', 'flag100_from_5114'], dtype='object') 0.8587575618149501
# Index(['flag100_to_5166', 'flag100_from_5116'], dtype='object') 0.8183442555964552
# Index(['flag100_to_5314', 'flag100_from_5382'], dtype='object') 0.8149315852547744
# Index(['flag100_to_5334', 'flag100_from_5334'], dtype='object') 0.8719143422121742
# Index(['flag100_to_5362', 'flag100_from_5124'], dtype='object') 0.8042237136912741
# Index(['flag100_to_5512', 'flag100_from_5512'], dtype='object') 0.831238953001313
# Index(['flag100_to_5562', 'flag100_to_5911'], dtype='object') 0.8154259391780683
# Index(['flag100_to_5562', 'flag100_from_5513'], dtype='object') 0.8089139107658878
# Index(['flag100_to_5911', 'flag100_to_5954'], dtype='object') 0.8132711626578709
# Index(['flag100_to_5911', 'flag100_from_5513'], dtype='object') 0.8118623503672882
# Index(['flag100_to_5911', 'flag100_from_5911'], dtype='object') 0.8898251496890841
# Index(['flag100_to_5911', 'flag100_from_5954'], dtype='object') 0.8059336551410468
# Index(['flag100_to_5913', 'flag100_from_5913'], dtype='object') 0.8408325804168151
# Index(['flag100_to_5914', 'flag100_to_5962'], dtype='object') 0.8117282754931855
# Index(['flag100_to_5914', 'flag100_from_5914'], dtype='object') 0.8601914669583229
# Index(['flag100_to_5915', 'flag100_from_5915'], dtype='object') 0.8580117776151714
# Index(['flag100_to_5916', 'flag100_from_5916'], dtype='object') 0.8701246455819834
# Index(['flag100_to_5954', 'flag100_from_5954'], dtype='object') 0.8366801844142256
# Index(['flag100_to_5962', 'flag100_from_5914'], dtype='object') 0.8020980502092461
# Index(['flag100_to_5962', 'flag100_from_5962'], dtype='object') 0.8055978142030322
# Index(['flag100_to_6411', 'flag100_to_6433'], dtype='object') 0.8059336551410538
# Index(['flag100_to_6413', 'flag100_to_6432'], dtype='object') 0.8061369432348775
# Index(['flag100_to_6434', 'flag100_to_6436'], dtype='object') 0.8580203176498139
# Index(['flag100_to_6435', 'flag100_from_6435'], dtype='object') 0.8015132183266646
# Index(['flag100_to_6436', 'flag100_to_6438'], dtype='object') 0.822033035944272
# Index(['flag100_to_6436', 'flag100_from_6412'], dtype='object') 0.8011979200317715
# Index(['flag100_to_6437', 'flag100_from_6437'], dtype='object') 0.8112592171905086
# Index(['flag100_to_6440', 'flag100_from_6440'], dtype='object') 0.832312908718893
# Index(['flag100_to_6535', 'flag100_from_6535'], dtype='object') 0.8277942546916107
# Index(['flag100_to_6636', 'flag100_from_6636'], dtype='object') 0.9022235982007282
# Index(['flag100_to_7132', 'flag100_from_7132'], dtype='object') 0.8277942546916116
# Index(['flag100_to_7140', 'flag100_from_7140'], dtype='object') 0.8365338358574422
# Index(['flag100_to_7231', 'flag100_from_7231'], dtype='object') 0.8277942546916258
# Index(['flag100_to_7232', 'flag100_from_7232'], dtype='object') 0.8430173252538732
# Index(['flag100_to_7311', 'flag100_to_7332'], dtype='object') 0.8365338358574422
# Index(['flag100_to_7312', 'flag100_from_7335'], dtype='object') 0.8045697175185278
# Index(['flag100_to_7313', 'flag100_from_7313'], dtype='object') 0.8138386663044748
# Index(['flag100_to_7318', 'flag100_to_7338'], dtype='object') 0.8046338656457886
# Index(['flag100_to_7320', 'flag100_from_7320'], dtype='object') 0.8921483919061072
# Index(['flag100_to_7332', 'flag100_to_7338'], dtype='object') 0.8157169117647048
# Index(['flag100_to_8117', 'flag100_from_8117'], dtype='object') 0.8090785477742984
# Index(['flag100_to_8125', 'flag100_from_8125'], dtype='object') 0.8224889143066079
# Index(['flag100_to_8222', 'flag100_to_8226'], dtype='object') 0.8121958343448632
# Index(['flag100_to_8226', 'flag100_from_8226'], dtype='object') 0.8316175574055614
# Index(['flag100_to_8231', 'flag100_from_8231'], dtype='object') 0.8437001138886604
# Index(['flag100_to_8235', 'flag100_from_8235'], dtype='object') 0.8117346543678889
# Index(['flag100_to_8236', 'flag100_from_8236'], dtype='object') 0.8207496275762622
# Index(['flag100_to_8237', 'flag100_from_8237'], dtype='object') 0.8829894278360896
# Index(['flag100_to_8316', 'flag100_to_8337'], dtype='object') 0.8308016877637131
# Index(['flag100_to_8316', 'flag100_from_8316'], dtype='object') 0.813390051283764
# Index(['flag100_to_8327', 'flag100_from_8327'], dtype='object') 0.8627051663700656
# Index(['flag100_to_8417', 'flag100_from_8417'], dtype='object') 0.8101752219841373
# Index(['flag100_to_9175', 'flag100_from_9175'], dtype='object') 0.822049475246192
# Index(['flag100_to_9176', 'flag100_from_9176'], dtype='object') 0.8856741143626675
# Index(['flag100_to_9183', 'flag100_from_9183'], dtype='object') 0.831300395323944
# Index(['flag100_to_9185', 'flag100_from_9185'], dtype='object') 0.9140959725792631
# Index(['flag100_to_9186', 'flag100_from_9186'], dtype='object') 0.8312389530013196
# Index(['flag100_to_9187', 'flag100_from_9187'], dtype='object') 0.8090785477742978
# Index(['flag100_to_9261', 'flag100_to_9274'], dtype='object') 0.8312389530013199
# Index(['flag100_to_9263', 'flag100_to_9278'], dtype='object') 0.85433248002829
# Index(['flag100_to_9271', 'flag100_from_9271'], dtype='object') 0.8978963099963921
# Index(['flag100_to_9273', 'flag100_from_9273'], dtype='object') 0.8365338358574432
# Index(['flag100_to_9274', 'flag100_to_9279'], dtype='object') 0.8046338656457852
# Index(['flag100_to_9363', 'flag100_from_9363'], dtype='object') 0.8212053569970491
# Index(['flag100_to_9373', 'flag100_from_9373'], dtype='object') 0.8773475542674192
# Index(['flag100_to_9374', 'flag100_from_9374'], dtype='object') 0.8495416570507461
# Index(['flag100_to_9461', 'flag100_from_9471'], dtype='object') 0.8795591660306565
# Index(['flag100_to_9474', 'flag100_from_9474'], dtype='object') 0.8543324800282913
# Index(['flag100_to_9565', 'flag100_from_9565'], dtype='object') 0.8123307548659574
# Index(['flag100_to_9573', 'flag100_from_9573'], dtype='object') 0.8909715675543285
# Index(['flag100_to_9575', 'flag100_from_9575'], dtype='object') 0.8000731223008412
# Index(['flag100_to_9576', 'flag100_from_9576'], dtype='object') 0.8519459876142192
# Index(['flag100_to_9662', 'flag100_to_9678'], dtype='object') 0.8166710620645068
# Index(['flag100_to_9677', 'flag100_from_9677'], dtype='object') 0.813838666304483
# Index(['flag100_to_9762', 'flag100_from_9762'], dtype='object') 0.8543324800282908
# Index(['flag100_to_9771', 'flag100_from_9771'], dtype='object') 0.8238239480834999
# Index(['flag100_to_9773', 'flag100_from_9773'], dtype='object') 0.8627051663700761
# Index(['flag100_to_9774', 'flag100_from_9774'], dtype='object') 0.8909715675543297
# Index(['flag100_to_9775', 'flag100_from_9775'], dtype='object') 0.8614899326279813
# Index(['flag100_to_9777', 'flag100_from_9762'], dtype='object') 0.8543324800282908
# Index(['flag100_to_9777', 'flag100_from_9777'], dtype='object') 0.8112592171905084
# Index(['flag100_to_9778', 'flag100_from_9778'], dtype='object') 0.877347554267423
# Index(['flag100_to_9779', 'flag100_from_9779'], dtype='object') 0.903960985240125
# Index(['flag100_to_10042', 'flag100_from_10042'], dtype='object') 0.9342265184725081
# Index(['flag100_to_10046', 'flag100_from_10046'], dtype='object') 0.8408201017764272
# Index(['flag100_to_12051', 'flag100_from_12051'], dtype='object') 0.8724554707379135
# Index(['flag100_to_12052', 'flag100_from_12052'], dtype='object') 0.8768929970683251
# Index(['flag100_to_12060', 'flag100_to_12065'], dtype='object') 0.8166710620645024
# Index(['flag100_to_12062', 'flag100_from_12062'], dtype='object') 0.8829894278361009
# Index(['flag100_to_12067', 'flag100_from_12067'], dtype='object') 0.8138386663044854
# Index(['flag100_to_12071', 'flag100_from_12071'], dtype='object') 0.8277942546916272
# Index(['flag100_to_13003', 'flag100_to_13004'], dtype='object') 0.9065268065268072
# Index(['flag100_to_13074', 'flag100_from_13074'], dtype='object') 0.8543445507756581
# Index(['flag100_to_14625', 'flag100_from_14625'], dtype='object') 0.8117346543679036
# Index(['flag100_to_14626', 'flag100_from_14626'], dtype='object') 0.8277942546916264
# Index(['flag100_to_14627', 'flag100_from_14627'], dtype='object') 0.8773475542674258
# Index(['flag100_to_14627', 'flag100_from_14628'], dtype='object') 0.808966701866034
# Index(['flag100_to_14628', 'flag100_from_14628'], dtype='object') 0.8313003953239411
# Index(['flag100_to_15001', 'flag100_from_15001'], dtype='object') 0.8166710620645041
# Index(['flag100_to_15082', 'flag100_to_15089'], dtype='object') 0.8089667018660347
# Index(['flag100_to_15082', 'flag100_from_15082'], dtype='object') 0.8301489545989349
# Index(['flag100_to_15091', 'flag100_from_15091'], dtype='object') 0.8112592171905078
# Index(['flag100_to_16052', 'flag100_from_16052'], dtype='object') 0.8216518399591456
# Index(['flag100_to_16056', 'flag100_from_16056'], dtype='object') 0.8796758876033117
# Index(['flag100_to_16071', 'flag100_from_16071'], dtype='object') 0.8166710620645053
# Index(['flag100_to_16074', 'flag100_from_16074'], dtype='object') 0.8313003953239396
# Index(['flag100_to_16075', 'flag100_from_16075'], dtype='object') 0.812330754865962
# Index(['flag100_from_1002', 'flag100_from_1058'], dtype='object') 0.8655607240449625
# Index(['flag100_from_1053', 'flag100_from_1062'], dtype='object') 0.814059265009015
# Index(['flag100_from_1057', 'flag100_from_1059'], dtype='object') 0.8138386663044617
# Index(['flag100_from_1058', 'flag100_from_1059'], dtype='object') 0.8000272548723402
# Index(['flag100_from_3102', 'flag100_from_3157'], dtype='object') 0.8281919451585267
# Index(['flag100_from_3102', 'flag100_from_3158'], dtype='object') 0.8281919451585267
# Index(['flag100_from_3103', 'flag100_from_3154'], dtype='object') 0.8543324800282883
# Index(['flag100_from_3153', 'flag100_from_3158'], dtype='object') 0.8437001138886652
# Index(['flag100_from_3157', 'flag100_from_3158'], dtype='object') 0.8281919451585266
# Index(['flag100_from_3452', 'flag100_from_3457'], dtype='object') 0.8138386663044647
# Index(['flag100_from_5111', 'flag100_from_5113'], dtype='object') 0.827832180902185
# Index(['flag100_from_5111', 'flag100_from_5158'], dtype='object') 0.8552943380030213
# Index(['flag100_from_5112', 'flag100_from_5170'], dtype='object') 0.8272340841242865
# Index(['flag100_from_5113', 'flag100_from_5158'], dtype='object') 0.8601655407798201
# Index(['flag100_from_5113', 'flag100_from_5562'], dtype='object') 0.8570306670679181
# Index(['flag100_from_5113', 'flag100_from_5911'], dtype='object') 0.8709426605879472
# Index(['flag100_from_5113', 'flag100_from_5913'], dtype='object') 0.86845141669806
# Index(['flag100_from_5114', 'flag100_from_5116'], dtype='object') 0.8808674985145554
# Index(['flag100_from_5114', 'flag100_from_5154'], dtype='object') 0.8411566646860746
# Index(['flag100_from_5114', 'flag100_from_5166'], dtype='object') 0.8470581755642523
# Index(['flag100_from_5116', 'flag100_from_5166'], dtype='object') 0.8470581755642523
# Index(['flag100_from_5117', 'flag100_from_5119'], dtype='object') 0.9213127715338977
# Index(['flag100_from_5117', 'flag100_from_5154'], dtype='object') 0.8183442555964546
# Index(['flag100_from_5117', 'flag100_from_5513'], dtype='object') 0.8194023390107636
# Index(['flag100_from_5119', 'flag100_from_5154'], dtype='object') 0.8244768104439367
# Index(['flag100_from_5119', 'flag100_from_5170'], dtype='object') 0.801707479777481
# Index(['flag100_from_5119', 'flag100_from_5513'], dtype='object') 0.8581659856968165
# Index(['flag100_from_5122', 'flag100_from_5316'], dtype='object') 0.804569717518529
# Index(['flag100_from_5158', 'flag100_from_5162'], dtype='object') 0.8191373267389105
# Index(['flag100_from_5158', 'flag100_from_5170'], dtype='object') 0.8026418015160824
# Index(['flag100_from_5158', 'flag100_from_5911'], dtype='object') 0.8241434777711922
# Index(['flag100_from_5162', 'flag100_from_5362'], dtype='object') 0.8104905242814782
# Index(['flag100_from_5170', 'flag100_from_5513'], dtype='object') 0.8040155162229755
# Index(['flag100_from_5314', 'flag100_from_5382'], dtype='object') 0.8093538840541422
# Index(['flag100_from_5362', 'flag100_from_5382'], dtype='object') 0.8602468137800823
# Index(['flag100_from_5513', 'flag100_from_5916'], dtype='object') 0.8194023390107638
# Index(['flag100_from_5515', 'flag100_from_5558'], dtype='object') 0.8089139107658881
# Index(['flag100_from_5515', 'flag100_from_5570'], dtype='object') 0.8411066934392822
# Index(['flag100_from_5562', 'flag100_from_5911'], dtype='object') 0.8530572757757774
# Index(['flag100_from_5562', 'flag100_from_5913'], dtype='object') 0.8299270123649879
# Index(['flag100_from_5570', 'flag100_from_5974'], dtype='object') 0.8220563781139802
# Index(['flag100_from_5711', 'flag100_from_5754'], dtype='object') 0.8197201800581371
# Index(['flag100_from_5911', 'flag100_from_5913'], dtype='object') 0.8227498940438452
# Index(['flag100_from_5911', 'flag100_from_5954'], dtype='object') 0.8382584904343724
# Index(['flag100_from_5911', 'flag100_from_5978'], dtype='object') 0.800154747732025
# Index(['flag100_from_5914', 'flag100_from_5962'], dtype='object') 0.843724606726053
# Index(['flag100_from_6411', 'flag100_from_6413'], dtype='object') 0.8070059624903567
# Index(['flag100_from_6411', 'flag100_from_6432'], dtype='object') 0.8470304034119388
# Index(['flag100_from_6414', 'flag100_from_6436'], dtype='object') 0.8022288030645238
# Index(['flag100_from_6414', 'flag100_from_7315'], dtype='object') 0.8218688041202528
# Index(['flag100_from_6434', 'flag100_from_6436'], dtype='object') 0.8362114430838289
# Index(['flag100_from_6435', 'flag100_from_6438'], dtype='object') 0.8110669842027847
# Index(['flag100_from_6436', 'flag100_from_6438'], dtype='object') 0.833608047401659
# Index(['flag100_from_6611', 'flag100_from_6633'], dtype='object') 0.8019894626050705
# Index(['flag100_from_7111', 'flag100_from_7137'], dtype='object') 0.8084421829945319
# Index(['flag100_from_7313', 'flag100_from_7316'], dtype='object') 0.8138386663044749
# Index(['flag100_from_7313', 'flag100_from_7318'], dtype='object') 0.813838666304475
# Index(['flag100_from_7314', 'flag100_from_7332'], dtype='object') 0.8194023390107604
# Index(['flag100_from_7314', 'flag100_from_7338'], dtype='object') 0.8756748647149502
# Index(['flag100_from_7315', 'flag100_from_7339'], dtype='object') 0.8523938340388127
# Index(['flag100_from_7316', 'flag100_from_7318'], dtype='object') 0.8614853195164083
# Index(['flag100_from_7316', 'flag100_from_7337'], dtype='object') 0.8000272548723394
# Index(['flag100_from_7332', 'flag100_from_7338'], dtype='object') 0.8991708680334438
# Index(['flag100_from_8115', 'flag100_from_8118'], dtype='object') 0.8133250750319659
# Index(['flag100_from_8222', 'flag100_from_8226'], dtype='object') 0.8266162223475817
# Index(['flag100_from_9374', 'flag100_from_9377'], dtype='object') 0.8665901232554706
# Index(['flag100_from_9463', 'flag100_from_9473'], dtype='object') 0.8166710620645077
# Index(['flag100_from_9562', 'flag100_from_9572'], dtype='object') 0.893247317539241
# Index(['flag100_from_9563', 'flag100_from_9573'], dtype='object') 0.8716746224400093
# Index(['flag100_from_9565', 'flag100_from_9576'], dtype='object') 0.813838666304482
# Index(['flag100_from_9663', 'flag100_from_9679'], dtype='object') 0.842409885829679
# Index(['flag100_from_12052', 'flag100_from_12066'], dtype='object') 0.8089667018660339
# Index(['flag100_from_12052', 'flag100_from_12071'], dtype='object') 0.9204996034892943
# Index(['flag100_from_12054', 'flag100_from_12069'], dtype='object') 0.8085862212690665
# Index(['flag100_from_12061', 'flag100_from_12067'], dtype='object') 0.8000272548723387
# Index(['flag100_from_12066', 'flag100_from_12071'], dtype='object') 0.808966701866034
# Index(['flag100_from_14511', 'flag100_from_14524'], dtype='object') 0.8019894626050801
# Index(['flag100_from_16052', 'flag100_from_16076'], dtype='object') 0.8216518399591458
# Index(['flag100_from_16055', 'flag100_from_16071'], dtype='object') 0.8166710620645049
# Index(['Std_i00i99krankhe', 'Std_j00j99krankhe'], dtype='object') 0.8295331522617919
# Index(['Std_i00i99krankhe', 'Std_k00k93krankhe'], dtype='object') 0.869301889675205
# Index(['Std_j00j99krankhe', 'Std_k00k93krankhe'], dtype='object') 0.8424116994717586

# %%
len(pairs)
len(set(pairs))
# Out:
# 359

# %%
#sns.heatmap(X[set(pairs)].corr())

# %% [markdown]
# # First CatBoost Model with 969 features

# %%
# initialize Pool
train_pool = Pool(X,Y)
 

# specify the training parameters 
model = CatBoostRegressor(random_seed=0, logging_level = 'Silent')
#train the model
cb = model.fit(train_pool)
print("R2 of final model on all data: ",cb.score(X, Y))
# Out:
# R2 of final model on all data:  0.9991887762219794

# %%
preds = cb.predict(train_pool,
                    prediction_type="RawFormulaVal"
                  )

print("RMSE of final model on all data: ", eval_metric(Y, preds, 'RMSE')[0])
# Out:
# RMSE of final model on all data:  1.0466854206842982

# %% [markdown]
# # SHAP VAlues

# %%
shap_values_cb = shap.TreeExplainer(cb).shap_values(X)

# %%
def ABS_SHAP(df_shap,df):
    # Make a copy of the input data
    shap_v = pd.DataFrame(df_shap)
    feature_list = df.columns
    shap_v.columns = feature_list
    df_v = df.copy().reset_index().drop('index',axis=1)
    
    # Determine the correlation in order to plot with different colors
    corr_list = list()
    for i in feature_list:
        b = np.corrcoef(shap_v[i],df_v[i])[1][0]
        corr_list.append(b)
    corr_df = pd.concat([pd.Series(feature_list),pd.Series(corr_list)],axis=1).fillna(0)
    # Make a data frame. Column 1 is the feature, and Column 2 is the correlation coefficient
    corr_df.columns  = ['Variable','Corr']
    corr_df['Sign'] = np.where(corr_df['Corr']>0,'red','blue')
    
    # Plot it
    shap_abs = np.abs(shap_v)
    k=pd.DataFrame(shap_abs.mean()).reset_index()
    k.columns = ['Variable','SHAP_abs']
    k2 = k.merge(corr_df,left_on = 'Variable',right_on='Variable',how='inner')
    k2 = k2.sort_values(by='SHAP_abs',ascending = True)[-20::]
    colorlist = k2['Sign']
    ax = k2.plot.barh(x='Variable',y='SHAP_abs',color = colorlist, figsize=(5,6),legend=False)
    ax.set_xlabel("SHAP Value (Red = Positive Impact)")
    
ABS_SHAP(shap_values_cb,X)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %%
shap.summary_plot(shap_values_cb,X)

# %% [markdown]
# # Second CatBoost model with 20 most important features

# %%
top20feature = X.columns[np.argsort(np.abs(shap_values_cb).mean(0))][-20:][::-1]
top10feature = X.columns[np.argsort(np.abs(shap_values_cb).mean(0))][-10:][::-1]

# %%
# initialize Pool
train_pool_20 = Pool(X[top20feature],Y)
 

# specify the training parameters 
model = CatBoostRegressor(random_seed=0, logging_level = 'Silent')
#train the model
cb_20 = model.fit(train_pool_20)
print("R2 of second model with top20 feature: ",cb_20.score(X[top20feature], Y))
# Out:
# R2 of second model with top20 feature:  0.995663905096807

# %%
preds_20 = cb_20.predict(train_pool_20,
                    prediction_type="RawFormulaVal"
                  )

print("RMSE of second model on top20 data: ", eval_metric(Y, preds_20, 'RMSE')[0])
# Out:
# RMSE of second model on top20 data:  2.4198877909926515

# %% [markdown]
# # Compare top 10 features of both Models

# %%
shap_values_cb_20 = shap.TreeExplainer(cb_20).shap_values(X[top20feature])

top10feature_from_top_20 = X[top20feature].columns[np.argsort(np.abs(shap_values_cb_20).mean(0))][-10:][::-1]

print("10 most important features from model with all features:", "\n", list(top10feature), "\n\n",
     "10 most important features from model with top20 features:", "\n", list(top10feature_from_top_20))
# Out:
# 10 most important features from model with all features:
#  ['std_inz_AGS_259to274', 'D_Auslae', 'G_longitude', 'SSE_Erholungs', 'INC_v1176', 'UE_v231', 'UE_v196', 'SSE_Wasserfla', 'SSE_Stickstof', 'D_fertil']
#
#  10 most important features from model with top20 features:
#  ['std_inz_AGS_259to274', 'G_longitude', 'D_Auslae', 'SSE_Stickstof', 'SSE_Wasserfla', 'PRE_Roemis', 'INC_v1176', 'D_fertil', 'UE_v196', 'IS_weg50kmundmehr2']

# %%
# features which are on top10 of both models:
for i in top10feature :
    if i in list(top10feature_from_top_20) :
         print(i)
# Out:
# std_inz_AGS_259to274
# D_Auslae
# G_longitude
# INC_v1176
# UE_v196
# SSE_Wasserfla
# SSE_Stickstof
# D_fertil

# %%
ABS_SHAP(shap_values_cb_20,X[top20feature])

# %%
shap.summary_plot(shap_values_cb_20,X[top20feature])

# %% [markdown]
# # Hold out validation of the second model

# %%
import random
iterations = range(0,20)

r2_reg_k_test_top20 = list(range(0,20))
rmse_reg_k_test_top20 = list(range(0,20))
r2_cb_k_train_top20 = list(range(0,20))
r2_cb_k_test_top20 = list(range(0,20))

for i in iterations:
    rs = random.sample(range(0,401), 80)
    k_test_x = X[top20feature].iloc[rs]
    k_test_y = Y.iloc[rs]
    k_train_x = X[top20feature].drop(rs)
    k_train_y = Y.drop(rs)
    # initialize Pool 
    train_pool_k = Pool(data=k_train_x,
                        label=k_train_y,
                        feature_names = list(X[top20feature].columns))
        
    test_pool_k = Pool(data=k_test_x,
                       label=k_test_y,
                       feature_names = list(X[top20feature].columns))

    
    #fit the model
    model = CatBoostRegressor(random_seed=0,
                              logging_level="Silent",
                              #iterations = scores_k.sort_values(by= "test-R2-mean")["iterations"].iloc[-1]
                             )

    cb_k = model.fit(train_pool_k)
    
    # make the prediction using the resulting model
    preds_k = cb_k.predict(test_pool_k,
                    prediction_type="RawFormulaVal"
                  )
    
    rmse_reg_k_test_top20[i] = eval_metric(np.array(k_test_y), preds_k, "RMSE")[0]
    
    preds_k = preds_k.reshape(-1, 1)
    #LinearRegression
    reg_k = LinearRegression().fit(preds_k, k_test_y)

    
    r2_cb_k_train_top20[i] = cb_k.score(train_pool_k)
    r2_reg_k_test_top20[i] = reg_k.score(preds_k, k_test_y)

    r2_cb_k_test_top20[i] =  cb_k.score(test_pool_k)
    
    print(i/len(iterations)*100,"%", "  " , end="")
# Out:
# 0.0 %   5.0 %   10.0 %   15.0 %   20.0 %   25.0 %   30.0 %   35.0 %   40.0 %   45.0 %   50.0 %   55.00000000000001 %   60.0 %   65.0 %   70.0 %   75.0 %   80.0 %   85.0 %   90.0 %   95.0 %

# %%
print("Mean R2 of CatBoost_models on train sets with top20 features:",sum(r2_cb_k_train_top20)/len(r2_cb_k_train_top20))
print("Mean R2 of linReg_modesl with top20 features: ", sum(r2_reg_k_test_top20)/len(r2_reg_k_test_top20))
print("Mean RMSE of CatBoost_models on test sets with top20 features: ", sum(rmse_reg_k_test_top20)/len(rmse_reg_k_test_top20))
print("Mean R2 of CatBoost_models on test sets with top20 features:",sum(r2_cb_k_test_top20)/len(r2_cb_k_test_top20))
# Out:
# Mean R2 of CatBoost_models on train sets with top20 features: 0.9971645517932315
# Mean R2 of linReg_modesl with top20 features:  0.4758587986372592
# Mean RMSE of CatBoost_models on test sets with top20 features:  27.334437329572303
# Mean R2 of CatBoost_models on test sets with top20 features: 0.46175273736814926

# %% [markdown]
# # descriptives of top20 features

# %%
X[top20feature].describe()
# Out:
#        std_inz_AGS_259to274    D_Auslae  G_longitude  SSE_Erholungs  \
# count            401.000000  401.000000   401.000000     401.000000
# mean              26.810415   10.034916     9.866997      70.509460
# std               19.821966    5.149191     2.026269      56.734703
# min                0.000000    1.900000     6.083333      14.000000
# 25%               13.653437    6.200000     8.216666      39.700001
# 50%               22.629042    9.200000     9.766666      52.799999
# 75%               36.430935   13.100000    11.416667      76.699997
# max              173.247955   35.000000    14.983334     384.600006
#
#         INC_v1176     UE_v231     UE_v196  SSE_Wasserfla  SSE_Stickstof  \
# count  401.000000  401.000000  401.000000     401.000000     401.000000
# mean    13.640155   15.151626   66.924667     123.133629      68.331635
# std      5.681263    3.232546    6.630356     181.269791      27.160891
# min     -7.500000    9.000000   44.299999       2.600000      21.400000
# 25%     10.200000   13.100000   62.700001      24.700001      47.500000
# 50%     13.600000   14.500000   67.599998      66.800003      59.200001
# 75%     16.500000   16.100000   71.300003     131.600006      88.199997
# max     42.599998   28.200001   81.599998    1918.000000     150.699997
#
#          D_fertil  UE_BeseimHan  HC_Stationae  flag100_from_5562    INC_v793  \
# count  401.000000    401.000000    401.000000         401.000000  401.000000
# mean     1.632220     13.988775     24.358616           0.144638   11.951619
# std      0.134031      4.891642      5.373880           0.352175    7.726850
# min      1.060000      0.000000     11.100000           0.000000  -25.000000
# 25%      1.560000     10.600000     20.400000           0.000000    7.300000
# 50%      1.650000     13.900000     23.700001           0.000000   12.300000
# 75%      1.720000     16.900000     27.500000           0.000000   16.200001
# max      1.940000     47.700001     43.299999           1.000000   46.000000
#
#        PRE_Roemis       SSE_v988  IS_weg50kmundmehr2  Std_a00b99bestimm  \
# count  401.000000     401.000000          401.000000         401.000000
# mean    32.242802   33367.324219           11.484292          79.408760
# std     24.361443   30681.789062            3.481254          18.671255
# min      1.700000    1062.000000            4.900000           0.000000
# 25%      7.900000   15678.000000            9.000000          69.467491
# 50%     29.100000   24587.000000           10.800000          78.406906
# 75%     52.299999   39522.000000           13.300000          90.140533
# max     87.800003  174293.000000           24.200001         133.675125
#
#        flag100_to_5374     UE_v324
# count       401.000000  401.000000
# mean          0.097257    1.128679
# std           0.296678    5.361213
# min           0.000000  -27.200001
# 25%           0.000000   -1.700000
# 50%           0.000000    1.200000
# 75%           0.000000    4.700000
# max           1.000000   20.799999

# %%
pd.DataFrame(Y).describe()
# Out:
#        std_inz_AGS_274to289
# count            401.000000
# mean              52.453857
# std               36.794933
# min                3.428815
# 25%               26.030115
# 50%               44.778191
# 75%               67.134506
# max              267.674591

# %%
frames = [ Y.describe(), X[top20feature].describe()]
des = pd.concat(frames, axis=1)
with pd.ExcelWriter(r"C:\Users\Constantin\Desktop\descriptives1.xlsx") as writer:  
    des.to_excel(writer, sheet_name='period 1')
